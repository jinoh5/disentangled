# %% [markdown]
# <a href="https://colab.research.google.com/github/jinoh5/disentangled/blob/main/beta2_regularization_included.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/drive/MyDrive/Ramon Lab
# Out:
# /content/drive/MyDrive/Ramon Lab

# %% [markdown]
# ## INPUT

# %%
import scipy
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import seaborn as sns
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D

# %%
# Hyperparameters
sigma = 1
N = 20 # 20 dimensional space
T = 100
numCond = 4
noise_var = 2

# %%
# original condition
org_cond = np.zeros((4,2))
org_cond[1,:] = [1,0]
org_cond[2,:] = [1,1]
org_cond[3,:] = [0,1]

# %%
def create_input(sigma, N, T, numCond, noise_var, train_test):
  # ACTUAL INPUT
  cond = np.zeros((4,2))
  cond[0,:] = [1,1]
  cond[1,:] = [-1,1]
  cond[2,:] = [-1,-1]
  cond[3,:] = [1,-1]

  cond = cond.T

  # Add noise
  input = np.zeros((numCond,T,N))
  # Project 'the square' to the N-dimensional space
  W = stats.norm.rvs(loc=0, scale=sigma, size=[N,2]) # this should go below
  for i in range(T): # T = 100 trials
      input[0,i,:] = W @ cond[:,0] # V (N x 1) = W (N x 2) * I (2 x 1)
      input[1,i,:] = W @ cond[:,1]
      input[2,i,:] = W @ cond[:,2]
      input[3,i,:] = W @ cond[:,3]

  # add very small Gaussian noise
  noise_matrix = np.random.normal(loc=0, scale=noise_var, size=input.shape)
  input_w_noise = input + noise_matrix

  # reshape
  input_dis = np.vstack((input_w_noise[0,:,:], input_w_noise[1,:,:], input_w_noise[2,:,:], input_w_noise[3,:,:]))

  # PCA
  pca = PCA(n_components = 3)
  transformed_data = pca.fit_transform(input_dis)

  fig = plt.figure()
  ax = fig.add_subplot(111, projection='3d')

  # Scatter plot the transformed data
  for _, (idx, color) in enumerate(zip(range(4), ['r','g','b','k'])):
      ax.scatter(transformed_data[idx*100:(idx+1)*100, 0],
                transformed_data[idx*100:(idx+1)*100, 1],
                transformed_data[idx*100:(idx+1)*100, 2],
                c=color, marker='o')

  # Set labels and title
  ax.set_xlabel('Principal Component 1')
  ax.set_ylabel('Principal Component 2')
  ax.set_zlabel('Principal Component 3')
  ax.set_title('3D Visualization of ' + str(train_test) + ' Data')
  ax.set_xlim([-10, 10])
  ax.set_ylim([-10, 10])
  ax.set_zlim([-10, 10])

  return input_dis

train_input = create_input(sigma, N, T, numCond, noise_var, 'train')
print(train_input.shape)
test_input = create_input(sigma, N, T, numCond, noise_var, 'test')
print(test_input.shape)
# Out:
# (400, 20)
# (400, 20)

# %% [markdown]
# ## Build Network

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, random_split, Subset

# %%
# Experiment conditions
task1 = org_cond[:,0]
task2 = org_cond[:,1]
xor = np.sum(org_cond,axis=1)%2

# %%
# Model 1 (nonlinear classifier)
class Simple_Nonlin(nn.Module):

  def __init__(self, input_dim, hidden_dim, output_dim):
    super(Simple_Nonlin, self).__init__()

    self.input_layer = nn.Linear(input_dim, hidden_dim)
    self.hidden_layer = nn.Linear(hidden_dim, output_dim) # here, I can add noise to make noises in the hidden layer

  def forward(self, x):

    x_h = F.relu(self.input_layer(x)) # Applying ReLU activation after input_layer
    output = self.hidden_layer(x_h)

    return x_h, output

# %%
# Hyperparameters
exp_cond = task1
n_trials_perpoint = 100
input = train_input
input_dim = 20
output_dim = 2
batchsize = 20
learning_rate = 0.001

# %%
# Experiment target
target = np.repeat(exp_cond, n_trials_perpoint)

input_tensor = torch.tensor(input, dtype=torch.float32)
target_tensor = torch.tensor(target, dtype=torch.long)

# Create a TensorDataset and DataLoader
dataset = TensorDataset(input_tensor, target_tensor)

# Define the size of train and test sets
train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size

# Split the dataset
train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

# Create train and test dataloaders
train_loader = DataLoader(train_dataset, batch_size = batchsize, shuffle=True) # shuffle the training dataset every time it starts a new epoch
test_loader = DataLoader(test_dataset, batch_size = batchsize, shuffle=False)

# hidden dim
hidden_dim = input_dim * 2

# Create an instance of a model
model = Simple_Nonlin(input_dim, hidden_dim, output_dim) # so that you can only input 'model' not 'modelName'
print(model)

# optimizer
optimizer = optim.Adam(model.parameters(), lr = learning_rate) # this is where I will add regularization metrics
# Out:
# Simple_Nonlin(
#   (input_layer): Linear(in_features=20, out_features=40, bias=True)
#   (hidden_layer): Linear(in_features=40, out_features=2, bias=True)
# )

# %%
def custom_loss(output, targets, sparsity, beta1, beta2):
  '''
  Custom loss function
  '''
  criterion = nn.CrossEntropyLoss() # you must instantiate the loss
  crossEntropyLoss = criterion(output, targets)
  totalLoss = beta1 * criterion(output, targets) + beta2 * sparsity

  return crossEntropyLoss, totalLoss

def L1_norm(hidden_output):
  l1_norm = torch.mean(torch.abs(hidden_output)) # gives me a simple number
  return l1_norm

# %%
# Hyperparameters
expname = "Task1"
regularization_model = L1_norm
num_epochs = 150
beta1 = 1
beta2 = 2.8 # increase the sparsity more (we changed to mean from sum. For sum case, beta2 was like 0.0001, but maybe for mean case, it might be different.)

# %%
# Training loop
trainLosses = []
valLosses = []
accuracies = []
sparsities = []
crossEntropyLosses = []

for epoch in range(num_epochs): # for every epoch

  # train set up
  model.train()
  train_loss = 0 # for every epoch, the loss is added across all batches
  sparsity_loss = 0
  crossEntropy_loss = 0

  for inputs, targets in train_loader: # During each epoch's training loop, when you iterate through 'train loader'
                                      # the batches ('inputs' and 'targets') are provided in a shuffled order.
                                      # this means that the order of data samples within each batch is randomized compared to the previous epoch

    inputs = inputs.float()

    # clear the gradients
    optimizer.zero_grad()

    # Apply the model
    x_h, output = model(inputs)

    # Compute sparsity from the hidden layer
    sparsity = regularization_model(x_h)
    sparsity_loss += sparsity

    # Compute the loss
    crossEntropyLoss, loss = custom_loss(output, targets, sparsity, beta1, beta2)
    crossEntropy_loss += crossEntropyLoss

    # Backpropagation
    loss.backward()

    # Update the weights
    optimizer.step()

    # Add loss
    train_loss += loss.item()

  avg_train_loss = train_loss / len(train_loader)
  trainLosses.append(avg_train_loss)

  avg_sparsity = sparsity_loss / len(train_loader)
  sparsities.append(avg_sparsity)

  avg_crossEntropy_loss = crossEntropy_loss/len(train_loader)
  crossEntropyLosses.append(avg_crossEntropy_loss)

  # Evaluation phase

  model.eval()
  val_loss = 0
  total = 0
  correct = 0

  with torch.no_grad(): # no need to track gradients during evaluation

    for inputs, targets in test_loader:

      # test input
      test_x_h, testoutput = model(inputs)

      # Compute sparsity from the hidden layer
      sparsity = regularization_model(test_x_h)

      # Compute the loss
      crossEntropyLoss, loss = custom_loss(testoutput, targets, sparsity, beta1, beta2)

      # find the validation loss
      val_loss += loss.item()

      # Get the max output?
      _, predicted = torch.max(testoutput, 1)

      # print("targets", targets)
      # print("predicted", predicted)

      # store the result
      total += targets.size(0)
      correct += (predicted == targets).sum().item()

    accuracy = correct / total
    accuracies.append(accuracy)

  # Average validation loss for this epoch
  avg_val_loss = val_loss / len(test_loader)
  valLosses.append(avg_val_loss)

  if (epoch+1) % 1 == 0:
    print(f'Epoch [{epoch+1}/{num_epochs}], Training Loss: {train_loss/len(train_loader):.4f}, Validation Loss: {val_loss/len(test_loader):.4f}')


sparsities_list = [tensor.detach().numpy() for tensor in sparsities]
crossEntropyLosses_list = [tensor.detach().numpy() for tensor in crossEntropyLosses]

# Plot train loss and validation loss and accuracy
epoch_nums = np.arange(num_epochs)+1

fig, axs = plt.subplots(1,3, figsize=(12,5))

axs[0].plot(epoch_nums, trainLosses, 'r')
axs[0].plot(epoch_nums, valLosses, 'b')
axs[0].set_title("Train / Validation Loss")
axs[0].set_xlabel("Epoch num")
axs[0].set_ylabel("Loss")
axs[0].legend(['Train loss', 'Validation loss'])
axs[0].set_ylim([0, 1])

axs[1].plot(epoch_nums, sparsities_list, 'g')
axs[1].plot(epoch_nums, crossEntropyLosses_list, 'k')
axs[1].legend(['Sparsity', 'Cross Entropy Loss'])
axs[1].set_title("Different losses")

axs[2].plot(epoch_nums, accuracies, 'g')
axs[2].set_title("Accuracy")
axs[2].set_xlabel("Epoch num")
axs[2].set_ylabel("Accuracy")
axs[2].set_ylim([0, 1])

plt.suptitle("Nonlinear classifier: " + str(expname))
plt.tight_layout()
plt.show()
# Out:
# Epoch [1/150], Training Loss: 2.2368, Validation Loss: 2.1043
# Epoch [2/150], Training Loss: 1.9191, Validation Loss: 1.9026
# Epoch [3/150], Training Loss: 1.7089, Validation Loss: 1.7433
# Epoch [4/150], Training Loss: 1.5557, Validation Loss: 1.6143
# Epoch [5/150], Training Loss: 1.4314, Validation Loss: 1.5084
# Epoch [6/150], Training Loss: 1.3266, Validation Loss: 1.4151
# Epoch [7/150], Training Loss: 1.2331, Validation Loss: 1.3314
# Epoch [8/150], Training Loss: 1.1488, Validation Loss: 1.2526
# Epoch [9/150], Training Loss: 1.0714, Validation Loss: 1.1791
# Epoch [10/150], Training Loss: 0.9976, Validation Loss: 1.1085
# Epoch [11/150], Training Loss: 0.9306, Validation Loss: 1.0433
# Epoch [12/150], Training Loss: 0.8677, Validation Loss: 0.9826
# Epoch [13/150], Training Loss: 0.8094, Validation Loss: 0.9221
# Epoch [14/150], Training Loss: 0.7561, Validation Loss: 0.8673
# Epoch [15/150], Training Loss: 0.7065, Validation Loss: 0.8171
# Epoch [16/150], Training Loss: 0.6604, Validation Loss: 0.7705
# Epoch [17/150], Training Loss: 0.6196, Validation Loss: 0.7299
# Epoch [18/150], Training Loss: 0.5824, Validation Loss: 0.6946
# Epoch [19/150], Training Loss: 0.5483, Validation Loss: 0.6570
# Epoch [20/150], Training Loss: 0.5186, Validation Loss: 0.6299
# Epoch [21/150], Training Loss: 0.4933, Validation Loss: 0.6062
# Epoch [22/150], Training Loss: 0.4702, Validation Loss: 0.5823
# Epoch [23/150], Training Loss: 0.4510, Validation Loss: 0.5632
# Epoch [24/150], Training Loss: 0.4334, Validation Loss: 0.5447
# Epoch [25/150], Training Loss: 0.4185, Validation Loss: 0.5285
# Epoch [26/150], Training Loss: 0.4051, Validation Loss: 0.5165
# Epoch [27/150], Training Loss: 0.3931, Validation Loss: 0.5035
# Epoch [28/150], Training Loss: 0.3825, Validation Loss: 0.4910
# Epoch [29/150], Training Loss: 0.3728, Validation Loss: 0.4819
# Epoch [30/150], Training Loss: 0.3641, Validation Loss: 0.4705
# Epoch [31/150], Training Loss: 0.3550, Validation Loss: 0.4616
# Epoch [32/150], Training Loss: 0.3475, Validation Loss: 0.4542
# Epoch [33/150], Training Loss: 0.3403, Validation Loss: 0.4463
# Epoch [34/150], Training Loss: 0.3335, Validation Loss: 0.4420
# Epoch [35/150], Training Loss: 0.3275, Validation Loss: 0.4349
# Epoch [36/150], Training Loss: 0.3219, Validation Loss: 0.4277
# Epoch [37/150], Training Loss: 0.3166, Validation Loss: 0.4223
# Epoch [38/150], Training Loss: 0.3116, Validation Loss: 0.4187
# Epoch [39/150], Training Loss: 0.3072, Validation Loss: 0.4148
# Epoch [40/150], Training Loss: 0.3036, Validation Loss: 0.4113
# Epoch [41/150], Training Loss: 0.2990, Validation Loss: 0.4050
# Epoch [42/150], Training Loss: 0.2953, Validation Loss: 0.4017
# Epoch [43/150], Training Loss: 0.2920, Validation Loss: 0.3960
# Epoch [44/150], Training Loss: 0.2884, Validation Loss: 0.3965
# Epoch [45/150], Training Loss: 0.2853, Validation Loss: 0.3940
# Epoch [46/150], Training Loss: 0.2823, Validation Loss: 0.3909
# Epoch [47/150], Training Loss: 0.2792, Validation Loss: 0.3868
# Epoch [48/150], Training Loss: 0.2767, Validation Loss: 0.3844
# Epoch [49/150], Training Loss: 0.2740, Validation Loss: 0.3825
# Epoch [50/150], Training Loss: 0.2712, Validation Loss: 0.3827
# Epoch [51/150], Training Loss: 0.2684, Validation Loss: 0.3806
# Epoch [52/150], Training Loss: 0.2663, Validation Loss: 0.3797
# Epoch [53/150], Training Loss: 0.2638, Validation Loss: 0.3778
# Epoch [54/150], Training Loss: 0.2616, Validation Loss: 0.3752
# Epoch [55/150], Training Loss: 0.2593, Validation Loss: 0.3747
# Epoch [56/150], Training Loss: 0.2577, Validation Loss: 0.3723
# Epoch [57/150], Training Loss: 0.2550, Validation Loss: 0.3711
# Epoch [58/150], Training Loss: 0.2534, Validation Loss: 0.3696
# Epoch [59/150], Training Loss: 0.2506, Validation Loss: 0.3690
# Epoch [60/150], Training Loss: 0.2494, Validation Loss: 0.3661
# Epoch [61/150], Training Loss: 0.2471, Validation Loss: 0.3651
# Epoch [62/150], Training Loss: 0.2455, Validation Loss: 0.3656
# Epoch [63/150], Training Loss: 0.2437, Validation Loss: 0.3602
# Epoch [64/150], Training Loss: 0.2420, Validation Loss: 0.3583
# Epoch [65/150], Training Loss: 0.2399, Validation Loss: 0.3554
# Epoch [66/150], Training Loss: 0.2386, Validation Loss: 0.3560
# Epoch [67/150], Training Loss: 0.2372, Validation Loss: 0.3574
# Epoch [68/150], Training Loss: 0.2355, Validation Loss: 0.3553
# Epoch [69/150], Training Loss: 0.2339, Validation Loss: 0.3505
# Epoch [70/150], Training Loss: 0.2327, Validation Loss: 0.3516
# Epoch [71/150], Training Loss: 0.2312, Validation Loss: 0.3499
# Epoch [72/150], Training Loss: 0.2297, Validation Loss: 0.3515
# Epoch [73/150], Training Loss: 0.2287, Validation Loss: 0.3481
# Epoch [74/150], Training Loss: 0.2274, Validation Loss: 0.3468
# Epoch [75/150], Training Loss: 0.2260, Validation Loss: 0.3511
# Epoch [76/150], Training Loss: 0.2246, Validation Loss: 0.3461
# Epoch [77/150], Training Loss: 0.2233, Validation Loss: 0.3453
# Epoch [78/150], Training Loss: 0.2224, Validation Loss: 0.3465
# Epoch [79/150], Training Loss: 0.2212, Validation Loss: 0.3386
# Epoch [80/150], Training Loss: 0.2197, Validation Loss: 0.3411
# Epoch [81/150], Training Loss: 0.2187, Validation Loss: 0.3418
# Epoch [82/150], Training Loss: 0.2177, Validation Loss: 0.3418
# Epoch [83/150], Training Loss: 0.2164, Validation Loss: 0.3394
# Epoch [84/150], Training Loss: 0.2151, Validation Loss: 0.3371
# Epoch [85/150], Training Loss: 0.2146, Validation Loss: 0.3328
# Epoch [86/150], Training Loss: 0.2128, Validation Loss: 0.3387
# Epoch [87/150], Training Loss: 0.2114, Validation Loss: 0.3364
# Epoch [88/150], Training Loss: 0.2107, Validation Loss: 0.3303
# Epoch [89/150], Training Loss: 0.2092, Validation Loss: 0.3295
# Epoch [90/150], Training Loss: 0.2083, Validation Loss: 0.3236
# Epoch [91/150], Training Loss: 0.2069, Validation Loss: 0.3257
# Epoch [92/150], Training Loss: 0.2064, Validation Loss: 0.3254
# Epoch [93/150], Training Loss: 0.2064, Validation Loss: 0.3181
# Epoch [94/150], Training Loss: 0.2039, Validation Loss: 0.3225
# Epoch [95/150], Training Loss: 0.2040, Validation Loss: 0.3214
# Epoch [96/150], Training Loss: 0.2020, Validation Loss: 0.3163
# Epoch [97/150], Training Loss: 0.2012, Validation Loss: 0.3156
# Epoch [98/150], Training Loss: 0.2000, Validation Loss: 0.3151
# Epoch [99/150], Training Loss: 0.2002, Validation Loss: 0.3113
# Epoch [100/150], Training Loss: 0.1982, Validation Loss: 0.3164
# Epoch [101/150], Training Loss: 0.1977, Validation Loss: 0.3098
# Epoch [102/150], Training Loss: 0.1967, Validation Loss: 0.3119
# Epoch [103/150], Training Loss: 0.1960, Validation Loss: 0.3120
# Epoch [104/150], Training Loss: 0.1954, Validation Loss: 0.3094
# Epoch [105/150], Training Loss: 0.1943, Validation Loss: 0.3095
# Epoch [106/150], Training Loss: 0.1930, Validation Loss: 0.3055
# Epoch [107/150], Training Loss: 0.1930, Validation Loss: 0.3090
# Epoch [108/150], Training Loss: 0.1920, Validation Loss: 0.3063
# Epoch [109/150], Training Loss: 0.1912, Validation Loss: 0.3042
# Epoch [110/150], Training Loss: 0.1900, Validation Loss: 0.3029
# Epoch [111/150], Training Loss: 0.1894, Validation Loss: 0.3017
# Epoch [112/150], Training Loss: 0.1886, Validation Loss: 0.3050
# Epoch [113/150], Training Loss: 0.1881, Validation Loss: 0.3023
# Epoch [114/150], Training Loss: 0.1869, Validation Loss: 0.2978
# Epoch [115/150], Training Loss: 0.1866, Validation Loss: 0.3023
# Epoch [116/150], Training Loss: 0.1854, Validation Loss: 0.2988
# Epoch [117/150], Training Loss: 0.1848, Validation Loss: 0.2992
# Epoch [118/150], Training Loss: 0.1840, Validation Loss: 0.2976
# Epoch [119/150], Training Loss: 0.1838, Validation Loss: 0.3002
# Epoch [120/150], Training Loss: 0.1830, Validation Loss: 0.2976
# Epoch [121/150], Training Loss: 0.1823, Validation Loss: 0.2971
# Epoch [122/150], Training Loss: 0.1813, Validation Loss: 0.2933
# Epoch [123/150], Training Loss: 0.1809, Validation Loss: 0.2960
# Epoch [124/150], Training Loss: 0.1797, Validation Loss: 0.2919
# Epoch [125/150], Training Loss: 0.1795, Validation Loss: 0.2938
# Epoch [126/150], Training Loss: 0.1787, Validation Loss: 0.2896
# Epoch [127/150], Training Loss: 0.1789, Validation Loss: 0.2959
# Epoch [128/150], Training Loss: 0.1774, Validation Loss: 0.2945
# Epoch [129/150], Training Loss: 0.1769, Validation Loss: 0.2917
# Epoch [130/150], Training Loss: 0.1756, Validation Loss: 0.2888
# Epoch [131/150], Training Loss: 0.1753, Validation Loss: 0.2926
# Epoch [132/150], Training Loss: 0.1749, Validation Loss: 0.2890
# Epoch [133/150], Training Loss: 0.1739, Validation Loss: 0.2921
# Epoch [134/150], Training Loss: 0.1732, Validation Loss: 0.2861
# Epoch [135/150], Training Loss: 0.1724, Validation Loss: 0.2898
# Epoch [136/150], Training Loss: 0.1717, Validation Loss: 0.2917
# Epoch [137/150], Training Loss: 0.1710, Validation Loss: 0.2972
# Epoch [138/150], Training Loss: 0.1705, Validation Loss: 0.2900
# Epoch [139/150], Training Loss: 0.1699, Validation Loss: 0.2909
# Epoch [140/150], Training Loss: 0.1701, Validation Loss: 0.2966
# Epoch [141/150], Training Loss: 0.1686, Validation Loss: 0.2851
# Epoch [142/150], Training Loss: 0.1679, Validation Loss: 0.2926
# Epoch [143/150], Training Loss: 0.1680, Validation Loss: 0.2880
# Epoch [144/150], Training Loss: 0.1667, Validation Loss: 0.2834
# Epoch [145/150], Training Loss: 0.1664, Validation Loss: 0.2888
# Epoch [146/150], Training Loss: 0.1661, Validation Loss: 0.2821
# Epoch [147/150], Training Loss: 0.1648, Validation Loss: 0.2941
# Epoch [148/150], Training Loss: 0.1645, Validation Loss: 0.2866
# Epoch [149/150], Training Loss: 0.1637, Validation Loss: 0.2840
# Epoch [150/150], Training Loss: 0.1637, Validation Loss: 0.2894

# %% [markdown]
# ## PCA on the output of the hidden layer

# %%
test_input_tensor = torch.tensor(test_input, dtype=torch.float32)

# evaluation mode
model.eval()

with torch.no_grad():
  new_x_h, output = model(test_input_tensor)

# with torch.no_grad():
#   new_x_h, output = model(input_tensor)

# %%
np.save("new_x_h_3", new_x_h)

# %%
# new_x_h = ne`w_x_h.detach().numpy()
pca = PCA(n_components = 3)
transformed_Xh = pca.fit_transform(new_x_h)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Scatter plot the transformed data
for _, (idx, color) in enumerate(zip(range(4), ['r','g','b','k'])):
    ax.scatter(transformed_Xh[idx*100:(idx+1)*100, 0],
               transformed_Xh[idx*100:(idx+1)*100, 1],
               transformed_Xh[idx*100:(idx+1)*100, 2],
               c=color, marker='o')


# Set labels and title (axis is important)
ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
ax.set_zlabel('Principal Component 3')
ax.set_title('Test input hidden layer activity')
ax.set_xlim([-3, 3])
ax.set_ylim([-3, 3])
ax.set_zlim([-3, 3])

plt.show()

# %% [markdown]
# ## Calculate the centroid and find the distances between the points

# %%
def calculate_centroid(points):
    x_coords = points[:, 0]
    y_coords = points[:, 1]
    z_coords = points[:, 2]
    centroid_x = np.mean(x_coords)
    centroid_y = np.mean(y_coords)
    centroid_z = np.mean(z_coords)

    return [centroid_x, centroid_y, centroid_z]

def find_euclidean_distance(onepoint, otherpoint):
    d = np.sqrt((onepoint[0] - otherpoint[0])**2 +
                (onepoint[1] - otherpoint[1])**2 +
                (onepoint[2] - otherpoint[2])**2)
    return d

# %%
trialNum = np.arange(0,500,100)

# calculate the centroid
total_centroid = np.zeros((4,3))
for i in range(len(trialNum)-1):
  total_centroid[i,:] = calculate_centroid(transformed_Xh[i:i+1,:])

# Plot the centroid
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

for _, (idx, color) in enumerate(zip(range(4), ['r','g','b','k'])):
    ax.scatter(total_centroid[idx:idx+1, 0],
               total_centroid[idx:idx+1, 1],
               total_centroid[idx:idx+1, 2],
               c=color, marker='o')

ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
ax.set_zlabel('Principal Component 3')
ax.set_xlim([-3, 3])
ax.set_ylim([-3, 3])
ax.set_zlim([-3, 3])
ax.legend([0,1,2,3], loc=1)

# calculate the distance
distances = []
for i in range(3):
    distances.append(find_euclidean_distance(total_centroid[0,:], total_centroid[i+1,:]))

print("                                        one,           two,               three")
print("Distances from the point 0 (red dots)", distances)

distances_2 = []
for i in [2,3]:
    distances_2.append(find_euclidean_distance(total_centroid[1,:], total_centroid[i,:]))

print("                                        two,               three")

print("Distances from the point 1 (green dots)", distances_2)


print("Distance from the point 2 to point 3)", find_euclidean_distance(total_centroid[2,:], total_centroid[3,:]))
# Out:
#                                         one,           two,               three
# Distances from the point 0 (red dots) [1.2316796002418555, 0.9995868763056446, 0.8381338426829069]
#                                         two,               three
# Distances from the point 1 (green dots) [0.28729965753204456, 0.5218079286258288]
# Distance from the point 2 to point 3) 0.2360174394849068

# %%
#
